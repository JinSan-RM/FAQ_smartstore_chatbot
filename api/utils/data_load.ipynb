# %%
import pickle
import pandas as pd

#data load and data check
#===========================================================================================
data = "C:/Users/Jinsan/Desktop/project/coxwave(과제)/RAG_chatbot/utils/final_result.pkl"

df = pd.read_pickle('utils/final_result.pkl')
# print(f"dataframe : {df.keys()}")
# print(f"dataframe : {df['[커머스API센터] 커머스API 이용은 유료인가요?']}")
# print(f"dataframe : {df['[쇼핑라이브 진행 조건] 라이브 방송 배경 및 촬영기준은 어떻게 되나요?']}")
# print(f"dataframe : {df['[커머스API센터] 커머스API 이용은 유료인가요?']}")
# json 형태의 pickle 데이터
# Q1. [커머스API센터] 커머스API 이용은 유료인가요
# A1. 현재 커머스API센터는 베타로 운영중이며, 베타 기간에는 무료로 제공됩니다. 향후 네이버 커머스API센터 운영정책에 따라 단위 시간 당 API 호출 총량의 제약이 있을 수 있으며, 제약의 정도를 설정하기에 따라 과금이 적용될 수 있습니
# 다. 


# 위 도움말이 도움이 되었나요?


# 별점1점

# 별점2점

# 별점3점

# 별점4점

# 별점5점



# 소중한 의견을 남겨주시면 보완하도록 노력하겠습니다.

# 보내기



# 도움말 닫기
# Q2. [쇼핑라이브 진행 조건] 라이브 방송 배경 및 촬영기준은 어떻게 되나요?
# A2. 라이브방송의 배경 및 촬영 기준은 판매자가 원하는 방향으로 자율로 운영합니다.라이브 방송 시 정면 풀샷이 아닌 수직샷 등 다양한 구도의 촬영도 가능하며 꼭 방송 중 판매자가 나오지 않고 다른 사람 또는 제품만 촬영도 가능 합니다
# .단. 배경음악의 경우 저작권 등에 문제 발생 될 수 있으므로 권장 드리지 않습니다.


# 위 도움말이 도움이 되었나요?


# 별점1점

# 별점2점

# 별점3점

# 별점4점

# 별점5점



# 소중한 의견을 남겨주시면 보완하도록 노력하겠습니다.

# 보내기



# 도움말 닫기
# Q3. [커머스API센터] 커머스API 이용은 유료인가요?
# A3. 현재 커머스API센터는 베타로 운영중이며, 베타 기간에는 무료로 제공됩니다. 향후 네이버 커머스API센터 운영정책에 따라 단위 시간 당 API 호출 총량의 제약이 있을 수 있으며, 제약의 정도를 설정하기에 따라 과금이 적용될 수 있습니
# 다. 


# 위 도움말이 도움이 되었나요?


# 별점1점

# 별점2점

# 별점3점

# 별점4점

# 별점5점



# 소중한 의견을 남겨주시면 보완하도록 노력하겠습니다.

# 보내기



# 도움말 닫기
#===========================================================================================
